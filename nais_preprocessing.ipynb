# %%
from nais.processor import make_config_template
make_config_template("/home/coliewo/Documents/Data Analysis/nais1.yml")

# %%
from nais.processor import nais_processor
nais_processor("/home/coliewo/Documents/Data Analysis/nais1.yml")
# Out:
# Processing 20240516 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240517 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240518 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240519 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240520 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240521 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240522 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240523 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240524 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240525 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240526 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240527 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240528 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240529 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# Processing 20240530 (Observatorio ISAC 'Open Lab' - BOLOGNA)
# ...

# %%
from nais.utils import combine_data
import pandas as pd
import xarray as xr

data_source = "/home/coliewo/Documents/Data Analysis/NPF/Data/NAIS/PROCESSED"
date_range = pd.date_range("2024-05-16","2025-02-01")

ds = combine_data(data_source, date_range, "1h",
    flag_sensitivity=0.5)

ds.to_netcdf("nais1_dataset.nc")

# %%
from nais.checker import startNaisChecker
startNaisChecker("nais1_dataset.nc", "bad_data_bounds.nc")
# Out:
# qt.qpa.plugin: Could not find the Qt platform plugin "wayland" in ""
# Saved: bad_data_bounds.nc
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 0
# /usr/lib/python3/dist-packages/IPython/core/interactiveshell.py:3561: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 3
#       1 from nais.utils import remove_bad_data
# ----> 3 ds = xr.open_dataset("nais1_dataset.nc")
#       4 bad_data = xr.open_dataset("bad_data_bounds.nc")
#       5 ds = remove_bad_data(ds, bad_data)
#
# NameError: name 'xr' is not defined
